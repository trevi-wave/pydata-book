# %%
import numpy as np
import pandas as pd
import sys as sys
import os
import requests
import sqlite3
np.random.seed(12345)
import matplotlib.pyplot as plt
plt.rc("figure", figsize=(10, 6))
pd.options.display.max_colwidth = 75
pd.options.display.max_columns = 20
np.set_printoptions(precision=4, suppress=True)

# %%
# !cd
# !type examples\ex1.csv
# Out:
# D:\Dev\pydata-book
# a,b,c,d,message
# 1,2,3,4,hello
# 5,6,7,8,world
# 9,10,11,12,foo

# %%
df = pd.read_csv("examples/ex1.csv")
df
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %%
pd.read_csv("examples/ex2.csv", header=None)
pd.read_csv("examples/ex2.csv", names=["a", "b", "c", "d", "message"])
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %%
names = ["a", "b", "c", "d", "message"]
pd.read_csv("examples/ex2.csv", names=names, index_col="message")
# Out:
#          a   b   c   d
# message
# hello    1   2   3   4
# world    5   6   7   8
# foo      9  10  11  12

# %%
# !type examples\csv_mindex.csv
parsed = pd.read_csv("examples/csv_mindex.csv",
                     index_col=["key1", "key2"])
parsed
# Out:
# key1,key2,value1,value2
# one,a,1,2
# one,b,3,4
# one,c,5,6
# one,d,7,8
# two,a,9,10
# two,b,11,12
# two,c,13,14
# two,d,15,16
#            value1  value2
# key1 key2
# one  a          1       2
#      b          3       4
#      c          5       6
#      d          7       8
# two  a          9      10
#      b         11      12
#      c         13      14
#      d         15      16

# %%
# !type examples\ex3.txt
# Out:
#             A         B         C
# aaa -0.264438 -1.026059 -0.619500
# bbb  0.927272  0.302904 -0.032399
# ccc -0.264273 -0.386314 -0.217601
# ddd -0.871858 -0.348382  1.100491

# %%
result = pd.read_csv("examples/ex3.txt", sep="\\s+")
result
# Out:
#             A         B         C
# aaa -0.264438 -1.026059 -0.619500
# bbb  0.927272  0.302904 -0.032399
# ccc -0.264273 -0.386314 -0.217601
# ddd -0.871858 -0.348382  1.100491

# %%
# !type examples\ex4.csv
pd.read_csv("examples/ex4.csv", skiprows=[0, 2, 3])
# Out:
# # hey!
# a,b,c,d,message
# # just wanted to make things more difficult for you
# # who reads CSV files with computers, anyway?
# 1,2,3,4,hello
# 5,6,7,8,world
# 9,10,11,12,foo
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %%
# !type examples\ex4.csv
pd.read_csv("examples/ex4.csv", comment='#')
# Out:
# # hey!
# a,b,c,d,message
# # just wanted to make things more difficult for you
# # who reads CSV files with computers, anyway?
# 1,2,3,4,hello
# 5,6,7,8,world
# 9,10,11,12,foo
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %%
# !type examples\ex5.csv
result = pd.read_csv("examples/ex5.csv")
result
# Out:
# something,a,b,c,d,message
# one,1,2,3,4,NA
# two,5,6,,8,world
# three,9,10,11,12,foo
#   something  a   b     c   d message
# 0       one  1   2   3.0   4     NaN
# 1       two  5   6   NaN   8   world
# 2     three  9  10  11.0  12     foo

# %%
pd.isna(result)
# Out:
#    something      a      b      c      d  message
# 0      False  False  False  False  False     True
# 1      False  False  False   True  False    False
# 2      False  False  False  False  False    False

# %%
result = pd.read_csv("examples/ex5.csv", na_values=["NULL"])
result
# Out:
#   something  a   b     c   d message
# 0       one  1   2   3.0   4     NaN
# 1       two  5   6   NaN   8   world
# 2     three  9  10  11.0  12     foo

# %%
result2 = pd.read_csv("examples/ex5.csv", keep_default_na=False)
result2
result2.isna()
result3 = pd.read_csv("examples/ex5.csv", keep_default_na=False,
                      na_values=["NA"])
result3
result3.isna()
# Out:
#    something      a      b      c      d  message
# 0      False  False  False  False  False     True
# 1      False  False  False  False  False    False
# 2      False  False  False  False  False    False

# %%
sentinels = {"message": ["foo", "NA"], "something": ["two"]}
pd.read_csv("examples/ex5.csv", na_values=sentinels,
            keep_default_na=False)

# %%
pd.options.display.max_rows = 10

# %%
result = pd.read_csv("examples/ex6.csv")
result
# Out:
#            one       two     three      four key
# 0     0.467976 -0.038649 -0.295344 -1.824726   L
# 1    -0.358893  1.404453  0.704965 -0.200638   B
# 2    -0.501840  0.659254 -0.421691 -0.057688   G
# 3     0.204886  1.074134  1.388361 -0.982404   R
# 4     0.354628 -0.133116  0.283763 -0.837063   Q
# ...        ...       ...       ...       ...  ..
# 9995  2.311896 -0.417070 -1.409599 -0.515821   L
# 9996 -0.479893 -0.650419  0.745152 -0.646038   E
# 9997  0.523331  0.787112  0.486066  1.093156   K
# 9998 -0.362559  0.598894 -1.843201  0.887292   G
# 9999 -0.096376 -1.012999 -0.657431 -0.573315   0
#
# [10000 rows x 5 columns]

# %%
pd.read_csv("examples/ex6.csv", nrows=5)

# %%
chunker = pd.read_csv("examples/ex6.csv", chunksize=1000)
type(chunker)

# %%
chunker = pd.read_csv("examples/ex6.csv", chunksize=1000)

tot = pd.Series([], dtype='int64')
for piece in chunker:
    tot = tot.add(piece["key"].value_counts(), fill_value=0)

tot = tot.sort_values(ascending=False)

# %%
tot[:10]

# %%
data = pd.read_csv("examples/ex5.csv")
data

# %%
import sys
data.to_csv(sys.stdout, sep="|")
# Out:
# |a|b|c
# 0|1|2|3
# 1|4|5|6
# 2|7|8|9

# %%
data.to_csv("examples/out.csv")
# !cat examples/out.csv

# %%
data.to_csv(sys.stdout, na_rep="NULL")

# %%
data.to_csv(sys.stdout, index=False, header=False)

# %%
data.to_csv(sys.stdout, index=False, columns=["a", "b", "c"])

# %%
# !cat examples/ex7.csv

# %%
import csv
f = open("examples/ex7.csv")
reader = csv.reader(f)

# %%
for line in reader:
    print(line)
f.close()

# %%
with open("examples/ex7.csv") as f:
    lines = list(csv.reader(f))

# %%
header, values = lines[0], lines[1:]

# %%
data_dict = {h: v for h, v in zip(header, zip(*values))}
data_dict

# %%
obj = """
{"name": "Wes",
 "cities_lived": ["Akron", "Nashville", "New York", "San Francisco"],
 "pet": null,
 "siblings": [{"name": "Scott", "age": 34, "hobbies": ["guitars", "soccer"]},
              {"name": "Katie", "age": 42, "hobbies": ["diving", "art"]}]
}
"""

# %%
import json
result = json.loads(obj)
result
# Out:
# {'name': 'Wes',
#  'cities_lived': ['Akron', 'Nashville', 'New York', 'San Francisco'],
#  'pet': None,
#  'siblings': [{'name': 'Scott', 'age': 34, 'hobbies': ['guitars', 'soccer']},
#   {'name': 'Katie', 'age': 42, 'hobbies': ['diving', 'art']}]}

# %%
asjson = json.dumps(result)
asjson
# Out:
# '{"name": "Wes", "cities_lived": ["Akron", "Nashville", "New York", "San Francisco"], "pet": null, "siblings": [{"name": "Scott", "age": 34, "hobbies": ["guitars", "soccer"]}, {"name": "Katie", "age": 42, "hobbies": ["diving", "art"]}]}'

# %%
siblings = pd.DataFrame(result["siblings"], columns=["name", "age"])
siblings
# Out:
#     name  age
# 0  Scott   34
# 1  Katie   42

# %%
# !type examples\example.json
# Out:
# [{"a": 1, "b": 2, "c": 3},
#  {"a": 4, "b": 5, "c": 6},
#  {"a": 7, "b": 8, "c": 9}]

# %%
data = pd.read_json("examples/example.json")
data
# Out:
#    a  b  c
# 0  1  2  3
# 1  4  5  6
# 2  7  8  9

# %%
print(data.to_json(sys.stdout))
print(data.to_json(sys.stdout, orient="records"))
# Out:
# {"a":{"0":1,"1":4,"2":7},"b":{"0":2,"1":5,"2":8},"c":{"0":3,"1":6,"2":9}}None
# [{"a":1,"b":2,"c":3},{"a":4,"b":5,"c":6},{"a":7,"b":8,"c":9}]None

# %%
tables = pd.read_html("examples/fdic_failed_bank_list.html")
len(tables)
failures = tables[0]
failures.head(10)
# Out:
#                                Bank Name               City          State  \
# 0     The First National Bank of Lindsay            Lindsay       Oklahoma
# 1  Republic First Bank dba Republic Bank       Philadelphia   Pennsylvania
# 2                          Citizens Bank           Sac City           Iowa
# 3               Heartland Tri-State Bank            Elkhart         Kansas
# 4                   First Republic Bank2      San Francisco     California
# 5                         Signature Bank           New York       New York
# 6                    Silicon Valley Bank        Santa Clara     California
# 7                      Almena State Bank             Almena         Kansas
# 8             First City Bank of Florida  Fort Walton Beach        Florida
# 9                   The First State Bank      Barboursville  West Virginia
#
#     Cert                 Aquiring Institution      Closing Date  \
# 0   4134   First Bank & Trust Co., Duncan, OK  October 18, 2024
# 1  27332    Fulton Bank, National Association    April 26, 2024
# 2   8758            Iowa Trust & Savings Bank  November 3, 2023
# 3  25851               Dream First Bank, N.A.     July 28, 2023
# 4  59017            JPMorgan Chase Bank, N.A.       May 1, 2023
# 5  57053                  Flagstar Bank, N.A.    March 12, 2023
# 6  24735  First Citizens Bank & Trust Company    March 10, 2023
# 7  15426                          Equity Bank  October 23, 2020
# 8  16748            United Fidelity Bank, fsb  October 16, 2020
# 9  14361                       MVB Bank, Inc.     April 3, 2020
#
#    Fund  Sort ascending
# 0                 10547
# 1                 10546
# 2                 10545
# 3                 10544
# 4                 10543
# 5                 10540
# 6                 10539
# 7                 10538
# 8                 10537
# 9                 10536

# %%
close_timestamps = pd.to_datetime(failures["Closing Date"])
close_timestamps.dt.year.value_counts().sort_index(ascending=False)
# Out:
# Closing Date
# 2024      2
# 2023      5
# 2020      4
# 2019      4
# 2017      8
# 2016      5
# 2015      8
# 2014     18
# 2013     24
# 2012     51
# 2011     92
# 2010    157
# 2009    140
# 2008     25
# 2007      3
# 2004      4
# 2003      3
# 2002     11
# 2001      4
# 2000      2
# Name: count, dtype: int64

# %%
from lxml import objectify

path = "datasets/mta_perf/Performance_MNR.xml"
with open(path) as f:
    parsed = objectify.parse(f)
root = parsed.getroot()

# %%
data = []

skip_fields = ["PARENT_SEQ", "INDICATOR_SEQ",
               "DESIRED_CHANGE", "DECIMAL_PLACES"]

for elt in root.INDICATOR:
    el_data = {}
    for child in elt.getchildren():
        if child.tag in skip_fields:
            continue
        el_data[child.tag] = child.pyval
    data.append(el_data)

# %%
perf = pd.DataFrame(data)
perf.head(10)
# Out:
#             AGENCY_NAME                        INDICATOR_NAME  \
# 0  Metro-North Railroad  On-Time Performance (West of Hudson)
# 1  Metro-North Railroad  On-Time Performance (West of Hudson)
# 2  Metro-North Railroad  On-Time Performance (West of Hudson)
# 3  Metro-North Railroad  On-Time Performance (West of Hudson)
# 4  Metro-North Railroad  On-Time Performance (West of Hudson)
# 5  Metro-North Railroad  On-Time Performance (West of Hudson)
# 6  Metro-North Railroad  On-Time Performance (West of Hudson)
# 7  Metro-North Railroad  On-Time Performance (West of Hudson)
# 8  Metro-North Railroad  On-Time Performance (West of Hudson)
# 9  Metro-North Railroad  On-Time Performance (West of Hudson)
#
#                                                                   DESCRIPTION  \
# 0  Percent of commuter trains that arrive at their destinations within 5 m...
# 1  Percent of commuter trains that arrive at their destinations within 5 m...
# 2  Percent of commuter trains that arrive at their destinations within 5 m...
# 3  Percent of commuter trains that arrive at their destinations within 5 m...
# 4  Percent of commuter trains that arrive at their destinations within 5 m...
# 5  Percent of commuter trains that arrive at their destinations within 5 m...
# 6  Percent of commuter trains that arrive at their destinations within 5 m...
# 7  Percent of commuter trains that arrive at their destinations within 5 m...
# 8  Percent of commuter trains that arrive at their destinations within 5 m...
# 9  Percent of commuter trains that arrive at their destinations within 5 m...
#
#    PERIOD_YEAR  PERIOD_MONTH            CATEGORY FREQUENCY INDICATOR_UNIT  \
# 0         2008             1  Service Indicators         M              %
# 1         2008             2  Service Indicators         M              %
# 2         2008             3  Service Indicators         M              %
# 3         2008             4  Service Indicators         M              %
# 4         2008             5  Service Indicators         M              %
# 5         2008             6  Service Indicators         M              %
# 6         2008             7  Service Indicators         M              %
# 7         2008             8  Service Indicators         M              %
# 8         2008             9  Service Indicators         M              %
# 9         2008            10  Service Indicators         M              %
#
#   YTD_TARGET YTD_ACTUAL MONTHLY_TARGET MONTHLY_ACTUAL
# 0       95.0       96.9           95.0           96.9
# 1       95.0       96.0           95.0           95.0
# 2       95.0       96.3           95.0           96.9
# 3       95.0       96.8           95.0           98.3
# 4       95.0       96.6           95.0           95.8
# 5       95.0       96.2           95.0           94.4
# 6       95.0       96.2           95.0           96.0
# 7       95.0       96.2           95.0           96.4
# 8       95.0       95.9           95.0           93.7
# 9       95.0       96.0           95.0           96.4

# %%
perf2 = pd.read_xml(path)
perf2.head()
# Out:
#    INDICATOR_SEQ  PARENT_SEQ           AGENCY_NAME  \
# 0          28445         NaN  Metro-North Railroad
# 1          28445         NaN  Metro-North Railroad
# 2          28445         NaN  Metro-North Railroad
# 3          28445         NaN  Metro-North Railroad
# 4          28445         NaN  Metro-North Railroad
#
#                          INDICATOR_NAME  \
# 0  On-Time Performance (West of Hudson)
# 1  On-Time Performance (West of Hudson)
# 2  On-Time Performance (West of Hudson)
# 3  On-Time Performance (West of Hudson)
# 4  On-Time Performance (West of Hudson)
#
#                                                                   DESCRIPTION  \
# 0  Percent of commuter trains that arrive at their destinations within 5 m...
# 1  Percent of commuter trains that arrive at their destinations within 5 m...
# 2  Percent of commuter trains that arrive at their destinations within 5 m...
# 3  Percent of commuter trains that arrive at their destinations within 5 m...
# 4  Percent of commuter trains that arrive at their destinations within 5 m...
#
#    PERIOD_YEAR  PERIOD_MONTH            CATEGORY FREQUENCY DESIRED_CHANGE  \
# 0         2008             1  Service Indicators         M              U
# 1         2008             2  Service Indicators         M              U
# 2         2008             3  Service Indicators         M              U
# 3         2008             4  Service Indicators         M              U
# 4         2008             5  Service Indicators         M              U
#
#   INDICATOR_UNIT  DECIMAL_PLACES YTD_TARGET YTD_ACTUAL MONTHLY_TARGET  \
# 0              %               1      95.00      96.90          95.00
# 1              %               1      95.00      96.00          95.00
# 2              %               1      95.00      96.30          95.00
# 3              %               1      95.00      96.80          95.00
# 4              %               1      95.00      96.60          95.00
#
#   MONTHLY_ACTUAL
# 0          96.90
# 1          95.00
# 2          96.90
# 3          98.30
# 4          95.80

# %%
frame = pd.read_csv("examples/ex1.csv")
frame
frame.to_pickle("examples/frame_pickle")

# %%
pd.read_pickle("examples/frame_pickle")
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %%
if os.path.exists("examples/frame_pickle"):
    os.remove("examples/frame_pickle")
    print("파일이 삭제되었습니다.")
else:
    print("파일이 존재하지 않습니다.")
# Out:
# 파일이 존재하지 않습니다.

# %%
file_path = 'datasets/fec/fec.parquet'
fec = pd.read_parquet(file_path)

# 파일 사이즈
print("Current Directory:", os.getcwd())
file_size = os.path.getsize(file_path)
print("File size (MB):", file_size)

# 1. 전체 메모리 사용량
total_size = fec.memory_usage(deep=True).sum() / (1024 * 1024)
print("Total memory  size (MB):", total_size)

# 2. 행과 열의 개수
num_rows, num_columns = fec.shape
print("Number of rows:", num_rows)
print("Number of columns:", num_columns)

# 3. 요약 정보
fec.info()
# Out:
# Current Directory: D:\02.Development\07.Trevi\pydata-book
# File size (MB): 27868001
# Total memory  size (MB): 707.3002414703369
# Number of rows: 1001731
# Number of columns: 16
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1001731 entries, 0 to 1001730
# Data columns (total 16 columns):
#  #   Column             Non-Null Count    Dtype
# ---  ------             --------------    -----
#  0   cmte_id            1001731 non-null  object
#  1   cand_id            1001731 non-null  object
#  2   cand_nm            1001731 non-null  object
#  3   contbr_nm          1001731 non-null  object
#  4   contbr_city        1001712 non-null  object
#  5   contbr_st          1001727 non-null  object
#  6   contbr_zip         1001620 non-null  object
#  7   contbr_employer    988002 non-null   object
#  8   contbr_occupation  993301 non-null   object
#  9   contb_receipt_amt  1001731 non-null  float64
#  10  contb_receipt_dt   1001731 non-null  object
#  11  receipt_desc       14166 non-null    object
#  12  memo_cd            92482 non-null    object
#  13  memo_text          97770 non-null    object
#  14  form_tp            1001731 non-null  object
#  15  file_num           1001731 non-null  int64
# dtypes: float64(1), int64(1), object(14)
# memory usage: 122.3+ MB

# %%
xlsx = pd.ExcelFile("examples/ex1.xlsx")

# %%
xlsx.sheet_names
# Out:
# ['Sheet1']

# %%
xlsx.parse(sheet_name="Sheet1")
# Out:
#    Unnamed: 0  a   b   c   d message
# 0           0  1   2   3   4   hello
# 1           1  5   6   7   8   world
# 2           2  9  10  11  12     foo

# %%
xlsx.parse(sheet_name="Sheet1", index_col=0)
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %%
frame = pd.read_excel("examples/ex1.xlsx", sheet_name="Sheet1")
frame
# Out:
#    Unnamed: 0  a   b   c   d message
# 0           0  1   2   3   4   hello
# 1           1  5   6   7   8   world
# 2           2  9  10  11  12     foo

# %%
writer = pd.ExcelWriter("examples/ex2.xlsx")
frame.to_excel(writer, sheet_name="Sheet1")
writer.close()

# %%
frame.to_excel("examples/ex2.xlsx")

# %%
os.remove("examples/ex2.xlsx")

# %%
if os.path.exists("examples/mydata.h5"):
    os.remove("examples/mydata.h5")
    print("파일이 삭제되었습니다.")
else:
    print("파일이 존재하지 않습니다.")
# Out:
# 파일이 존재하지 않습니다.

# %%
frame = pd.DataFrame({"a": np.random.standard_normal(100)})
store = pd.HDFStore("examples/mydata.h5")
store["obj1"] = frame
store["obj1_col"] = frame["a"]
store
# Out:
# <class 'pandas.io.pytables.HDFStore'>
# File path: examples/mydata.h5

# %%
store["obj1"]
# Out:
#            a
# 0  -0.204708
# 1   0.478943
# 2  -0.519439
# 3  -0.555730
# 4   1.965781
# ..       ...
# 95  0.795253
# 96  0.118110
# 97 -0.748532
# 98  0.584970
# 99  0.152677
#
# [100 rows x 1 columns]

# %%
store.put("obj2", frame, format="table")
store.select("obj2", where=["index >= 10 and index <= 15"])
store.close()

# %%
frame.to_hdf(path_or_buf="examples/mydata.h5", key="obj3", format="table") # Pandas 3.0부터 to_hdf() 함수의 모든 인자가 키워드 전용으로 변경될 것임을 알리는 경고입니다. 즉, to_hdf() 함수에서 path_or_buf 외의 모든 인자는 키워드 인자로 명시
pd.read_hdf("examples/mydata.h5", "obj3", where=["index < 5"])
# Out:
#           a
# 0 -0.204708
# 1  0.478943
# 2 -0.519439
# 3 -0.555730
# 4  1.965781

# %%
import os
os.remove("examples/mydata.h5")

# %%
url = "https://api.github.com/repos/pandas-dev/pandas/issues"
resp = requests.get(url)
resp.raise_for_status()
resp
# Out:
# <Response [200]>

# %%
data = resp.json()
data[0]["title"]
# Out:
# 'ENH: When running json_normalize over a pandas dataframe, be able to insert/keep an index/Id series/column'

# %%
issues = pd.DataFrame(data, columns=["number", "title",
                                     "labels", "state"])
issues
# Out:
#     number  \
# 0    60272
# 1    60271
# 2    60270
# 3    60269
# 4    60268
# 5    60267
# 6    60266
# 7    60265
# 8    60264
# 9    60263
# 10   60261
# 11   60259
# 12   60258
# 13   60257
# 14   60255
# 15   60254
# 16   60253
# 17   60252
# 18   60251
# 19   60247
# 20   60239
# 21   60237
# 22   60236
# 23   60235
# 24   60234
# 25   60229
# 26   60228
# 27   60227
# 28   60218
# 29   60214
#
#                                                                          title  \
# 0   ENH: When running json_normalize over a pandas dataframe, be able to in...
# 1                                     decorate isna with @set_module('pandas')
# 2                                             add parametrization to the tests
# 3                                                             IndexSliceupdate
# 4   decorate `pandas.core.groupby.generic` classes with `@set_module('panda...
# 5                      decorate `timedelta_range` with `@set_module('pandas')`
# 6            decorate merge functions in merge.py with `@set_module('pandas')`
# 7       decorate `read_*` functions in readers.py with `@set_module('pandas')`
# 8        Decorate `date_range` and `bdate_range` with  `@set_module('pandas')`
# 9                ENH: set `__module__` with `set_module` decorator on `Series`
# 10                                     ENH: Set __module__ on StringDatatypes
# 11                                Solution to issue #49725 did changes in  DOC
# 12           REF: Replace maybe_infer_to_datimelike with maybe_convert_objects
# 13  [backport 2.3.x] TST (string dtype): resolve xfails in pandas/tests/cop...
# 14                  TST (string dtype): fix sql xfails with using_infer_string
# 15  BUG: Challenges with Nested Metadata Extraction Using pandas.json_norma...
# 16  TST: Add test for visibility of x label and xtick labels for `plot.hexbin`
# 17          DOC: fix SA01,ES01 for pandas.core.groupby.DataFrameGroupBy.groups
# 18                      BUG: remove single quotes in index names when printing
# 19    DOC: Additions/updates documentation for df.interpolate() methods #60227
# 20                   Fix Bug: last column missing formatting in Latex (#52218)
# 21  BUG: `.convert_dtypes(dtype_backend="pyarrow")` strips timezone from tz...
# 22                       BUG: .duplicated() ignoring duplicates for MultiIndex
# 23  ENH (string dtype): convert string_view columns to future string dtype ...
# 24          BUG (string dtype): logical operation with bool and string failing
# 25                       BUG/API: sum of a string column with all-NaN or empty
# 26  BUG (string dtype): comparison of string column to mixed object column ...
# 27  DOC: Improve documentation df.interpolate() for methods   ‘time’, ‘inde...
# 28               ERR: consistent error messages for unsupported setitem values
# 29  BUG: Creation of UInt64 column with 18446744073709551615 throws Runtime...
#
#                                                                         labels  \
# 0   [{'id': 76812, 'node_id': 'MDU6TGFiZWw3NjgxMg==', 'url': 'https://api.g...
# 1   [{'id': 13101118, 'node_id': 'MDU6TGFiZWwxMzEwMTExOA==', 'url': 'https:...
# 2   [{'id': 127685, 'node_id': 'MDU6TGFiZWwxMjc2ODU=', 'url': 'https://api....
# 3   [{'id': 13101118, 'node_id': 'MDU6TGFiZWwxMzEwMTExOA==', 'url': 'https:...
# 4   [{'id': 13101118, 'node_id': 'MDU6TGFiZWwxMzEwMTExOA==', 'url': 'https:...
# 5   [{'id': 13101118, 'node_id': 'MDU6TGFiZWwxMzEwMTExOA==', 'url': 'https:...
# 6   [{'id': 13101118, 'node_id': 'MDU6TGFiZWwxMzEwMTExOA==', 'url': 'https:...
# 7   [{'id': 13101118, 'node_id': 'MDU6TGFiZWwxMzEwMTExOA==', 'url': 'https:...
# 8   [{'id': 13101118, 'node_id': 'MDU6TGFiZWwxMzEwMTExOA==', 'url': 'https:...
# 9   [{'id': 13101118, 'node_id': 'MDU6TGFiZWwxMzEwMTExOA==', 'url': 'https:...
# 10  [{'id': 13101118, 'node_id': 'MDU6TGFiZWwxMzEwMTExOA==', 'url': 'https:...
# 11                                                                          []
# 12  [{'id': 211029535, 'node_id': 'MDU6TGFiZWwyMTEwMjk1MzU=', 'url': 'https...
# 13                                                                          []
# 14                                                                          []
# 15  [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ==', 'url': 'https://api.g...
# 16  [{'id': 2413328, 'node_id': 'MDU6TGFiZWwyNDEzMzI4', 'url': 'https://api...
# 17                                                                          []
# 18  [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ==', 'url': 'https://api.g...
# 19  [{'id': 134699, 'node_id': 'MDU6TGFiZWwxMzQ2OTk=', 'url': 'https://api....
# 20  [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ==', 'url': 'https://api.g...
# 21  [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ==', 'url': 'https://api.g...
# 22  [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ==', 'url': 'https://api.g...
# 23  [{'id': 57522093, 'node_id': 'MDU6TGFiZWw1NzUyMjA5Mw==', 'url': 'https:...
# 24  [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ==', 'url': 'https://api.g...
# 25  [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ==', 'url': 'https://api.g...
# 26  [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ==', 'url': 'https://api.g...
# 27  [{'id': 134699, 'node_id': 'MDU6TGFiZWwxMzQ2OTk=', 'url': 'https://api....
# 28  [{'id': 2822098, 'node_id': 'MDU6TGFiZWwyODIyMDk4', 'url': 'https://api...
# 29  [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ==', 'url': 'https://api.g...
#
#    state
# 0   open
# 1   open
# 2   open
# 3   open
# 4   open
# 5   open
# 6   open
# 7   open
# 8   open
# 9   open
# 10  open
# 11  open
# 12  open
# 13  open
# 14  open
# 15  open
# 16  open
# 17  open
# 18  open
# 19  open
# 20  open
# 21  open
# 22  open
# 23  open
# 24  open
# 25  open
# 26  open
# 27  open
# 28  open
# 29  open

# %%
query = """
CREATE TABLE test
(a VARCHAR(20), b VARCHAR(20),
 c REAL,        d INTEGER
);"""

con = sqlite3.connect("mydata.sqlite")
con.execute(query)
con.commit()

# %%
data = [("Atlanta", "Georgia", 1.25, 6),
        ("Tallahassee", "Florida", 2.6, 3),
        ("Sacramento", "California", 1.7, 5)]
stmt = "INSERT INTO test VALUES(?, ?, ?, ?)"

con.executemany(stmt, data)
con.commit()

# %%
cursor = con.execute("SELECT * FROM test")
rows = cursor.fetchall()
rows
# Out:
# [('Atlanta', 'Georgia', 1.25, 6),
#  ('Tallahassee', 'Florida', 2.6, 3),
#  ('Sacramento', 'California', 1.7, 5)]

# %%
cursor.description
pd.DataFrame(rows, columns=[x[0] for x in cursor.description])
# Out:
#              a           b     c  d
# 0      Atlanta     Georgia  1.25  6
# 1  Tallahassee     Florida  2.60  3
# 2   Sacramento  California  1.70  5

# %%
import sqlalchemy as sqla
db = sqla.create_engine("sqlite:///mydata.sqlite")
pd.read_sql("SELECT * FROM test", db)
# Out:
#              a           b     c  d
# 0      Atlanta     Georgia  1.25  6
# 1  Tallahassee     Florida  2.60  3
# 2   Sacramento  California  1.70  5

# %%
con.close()
db.dispose()

# %%
os.remove("mydata.sqlite")
